# %% [markdown]
# ## Imports

# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd

import acquire as a

# %% [markdown]
# ## Acquire the data

# %%
urls = a.get_blog_urls()
articles = a.get_news_articles()

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises
#  Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# - Lowercase everything
# - Normalize unicode characters
# - Replace anything that is not a letter, number, whitespace or a single quote.

# %%
string = articles.content[0]
string
# Out:
# "The rupee hit a record low of 79.97 against the US dollar on Monday after opening at 79.76. The Finance Ministry, while speaking about the matter said that global factors such as the Russia-Ukraine war, soaring crude oil prices and tightening of global financial conditions are the major reasons for the rupee's weakening."

# %%
# creating the function
def basic_clean(string):
    
    # lowercase everything
    string = string.lower()
    
    # remove inconsistenceis
    # encode into ascii byte strings
    # decode back into UTF-8
    # (This process will normalize the unicode characters)
    
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('UTF-8')
    
    # replace anything that is not a letter, number, whitespace, etc
    # use regex to perform this operation
    string = re.sub(r"[^a-z0-9\s]", '', string)
    
    return string

# %%
cleaned_string = basic_clean(string)
cleaned_string
# Out:
# 'the rupee hit a record low of 7997 against the us dollar on monday after opening at 7976 the finance ministry while speaking about the matter said that global factors such as the russiaukraine war soaring crude oil prices and tightening of global financial conditions are the major reasons for the rupees weakening'

# %% [markdown]
# ---

# %% [markdown]
# Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    """
    This function will take in a string, tokenize the string and 
    return the tokenize string
    """
    
    #create the token
    token = nltk.tokenize.ToktokTokenizer()
    
    #Use the token
    string = token.tokenize(string,  return_str=True)
    
    return string

# %%
token = tokenize(cleaned_string)
token
# Out:
# 'the rupee hit a record low of 7997 against the us dollar on monday after opening at 7976 the finance ministry while speaking about the matter said that global factors such as the russiaukraine war soaring crude oil prices and tightening of global financial conditions are the major reasons for the rupees weakening'

# %% [markdown]
# ---

# %% [markdown]
# Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    """
    This function will accept some text(string) and return a stemmed 
    version of the text
    """
    
    #create the porter stem
    ps = nltk.porter.PorterStemmer()
    
    #Apply the stem to each work in the string and create a list
    # of steemed words
    
    stem = [ps.stem(word) for word in string.split()]
    
    # rejoin the string together
    stemmed_string = ' '.join(stem)
    
    return stemmed_string

# %%
#test
stemmed_string = stem(token)
stemmed_string
# Out:
# 'the rupe hit a record low of 7997 against the us dollar on monday after open at 7976 the financ ministri while speak about the matter said that global factor such as the russiaukrain war soar crude oil price and tighten of global financi condit are the major reason for the rupe weaken'

# %% [markdown]
# ---

# %% [markdown]
# Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
# download wornet lemmatized
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/deangelobowen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize(string):
    """This function takes in a string and returns a lmeeatized 
    version of the string"""
    
    # create the lemmatizer
    wnl = nltk.stem.WordNetLemmatizer()
    
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    
    string_lemmatize = ' '.join(lemmas)
    
    return string_lemmatize

# %%
lemmatized = lemmatize(token)
lemmatized
# Out:
# 'the rupee hit a record low of 7997 against the u dollar on monday after opening at 7976 the finance ministry while speaking about the matter said that global factor such a the russiaukraine war soaring crude oil price and tightening of global financial condition are the major reason for the rupee weakening'

# %% [markdown]
# ---

# %% [markdown]
# Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.

# %% [markdown]
# This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
def remove_stopwords(string, extra_words=[], exclude_words=[]):
    """
    This function will take in a string, filter out stop words from the nltk standard english list 
    as well as any other extra words, and return a version of the text without these stopwords.
    It includes optional paramaters allowing the user to add extra words to remove 
    or to exclude words from the stopword list.
    """
    
    #get english stopwords from nltk
    stop_words = stopwords.words('english')
    
    #Add extra words to be removed to the stop word list
    for word in extra_words:
        stop_words.append(word)
    
    #Remove words to be excluded from the stop word list
    for word in exclude_words:
        stop_words.remove(word)
    
    #Create a list of words to be checked by splitting the string
    words = string.split()
    
    #Filter out all of the stop words
    filtered_words = [word for word in words if word not in stop_words]
    
    #Join the list of filtered words into a string
    filtered_string = ' '.join(filtered_words)
    
    return filtered_string

# %%
removed_stopwords = remove_stopwords(token)
removed_stopwords
# Out:
# 'rupee hit record low 7997 us dollar monday opening 7976 finance ministry speaking matter said global factors russiaukraine war soaring crude oil prices tightening global financial conditions major reasons rupees weakening'

# %%
# Test using extra_words and exclude_words options
extra_words = ['russia', 'matter']
exclude_words = ['the']

filters = remove_stopwords(token, extra_words, exclude_words)
filters
# Out:
# 'the rupee hit record low 7997 the us dollar monday opening 7976 the finance ministry speaking the said global factors the russiaukraine war soaring crude oil prices tightening global financial conditions the major reasons the rupees weakening'

# %% [markdown]
# ---

# %% [markdown]
# Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news_df = a.get_news_articles()
news_df
# Out:
#          category                                              title  \
# 0        business   Rupee hits record low of 79.97 against US dollar
# 1        business  Rupee closes at an all-time low of 79.98 again...
# 2        business  BCCI had ₹40 cr in bank when I joined & ₹47,68...
# 3        business  A fighter to the core: Mahindra praises PV Sin...
# 4        business  It is not a sacrifice at all: Bill Gates on pl...
# ..            ...                                                ...
# 95  entertainment  Excited to announce my next film starring Kart...
# 96  entertainment  8-yr-old Aditya Patil wins Dance Deewane Junio...
# 97  entertainment  Grace & style of Dhanush is something to behol...
# 98  entertainment  Rajesh Khanna was very generous, he bought hou...
# 99  entertainment  Had no money, cried myself to sleep: Monica Ch...
#
#             author       date  \
# 0   Ridham Gambhir 2022-07-18
# 1   Ridham Gambhir 2022-07-18
# 2   Ridham Gambhir 2022-07-17
# 3   Ridham Gambhir 2022-07-17
# 4      Hiral Goyal 2022-07-17
# ..             ...        ...
# 95  Amartya Sharma 2022-07-18
# 96      Udit Gupta 2022-07-18
# 97  Amartya Sharma 2022-07-18
# 98      Udit Gupta 2022-07-18
# 99      Udit Gupta 2022-07-18
#
#                                               content
# 0   The rupee hit a record low of 79.97 against th...
# 1   The rupee on Monday hit a fresh record low as ...
# 2   In an Instagram post, Lalit Modi asserted that...
# 3   Businessman Anand Mahindra took to Twitter to ...
# 4   Microsoft Co-founder Bill Gates, who plans to ...
# ..                                                ...
# 95  Filmmaker Kabir Khan took to Instagram to anno...
# 96  Aditya Patil has won the first season of the t...
# 97  Regé-Jean Page, speaking about Dhanush in 'The...
# 98  Veteran actress Sharmila Tagore, who appeared ...
# 99  Actress Monica Chauudhary, known for shows lik...
#
# [100 rows x 5 columns]

# %% [markdown]
# Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
codeup_df = a.get_blog_articles()
codeup_df
# Out:
# Using cached .json file
#                                                 title       date  \
# 0   In-Person Workshop: Learn to Code – Python on ... 2022-06-20
# 1   Free JavaScript Workshop at Codeup Dallas on 6/28 2022-06-19
# 2   Is Our Cloud Administration Program Right for ... 2022-06-08
# 3                                 PRIDE in Tech Panel 2022-06-05
# 4   Inclusion at Codeup During Pride Month (and Al... 2022-06-01
# 5                    Mental Health First Aid Training 2022-05-31
# 6   Codeup Dallas: How to Succeed at a Coding Boot... 2022-05-23
# 7   5 Reasons To Attend Our New Cloud Administrati... 2022-05-17
# 8                       Learn to Code: Python on 5/21 2022-05-16
# 9                      Codeup Dallas Joins Career Day 2022-05-16
# 10  Project Quest Info Session: IT Jumpstart on Ma... 2022-05-11
# 11  From Bootcamp to Bootcamp | A Military Appreci... 2022-04-27
# 12  Our Acquisition of the Rackspace Cloud Academy... 2022-04-14
# 13                  Learn to Code: HTML & CSS on 4/30 2022-04-01
# 14             Learn to Code: Python Workshop on 4/23 2022-03-31
#
#                          category  \
# 0                     San Antonio
# 1                          Dallas
# 2                        Featured
# 3                          Dallas
# 4                     Codeup News
# 5   Tips for Prospective Students
# 6                          Dallas
# 7                     Codeup News
# 8                          Events
# 9                     Codeup News
# 10                    San Antonio
# 11                 Alumni Stories
# 12                    Codeup News
# 13                        Virtual
# 14                         Events
#
#                                               content
# 0   According to LinkedIn, the “#1 Most Promising ...
# 1   Event Info:  Location – Codeup Dallas Time – 6...
# 2   Changing careers can be scary. The first thing...
# 3   In celebration of PRIDE month, join our Codeup...
# 4   Happy Pride Month! Pride Month is a dedicated ...
# 5   As a student of Codeup, going through a massiv...
# 6   This event is the perfect opportunity for peop...
# 7   Come Work In The Cloud When your Monday rolls ...
# 8   According to LinkedIn, the “#1 Most Promising ...
# 9   Last week our Codeup Dallas team participated ...
# 10  Join our grant partner Project Quest as they d...
# 11  In honor of Military Appreciation Month, join ...
# 12  Just about a year ago on April 16th, 2021 we a...
# 13  HTML & CSS are the design building blocks of a...
# 14  According to LinkedIn, the “#1 Most Promising ...

# %% [markdown]
# ---

# %% [markdown]
# For each dataframe, produce the following columns:
#
# - title to hold the title
# - original to hold the original article/post content
# - clean to hold the normalized and tokenized original with the stopwords removed.
# - stemmed to hold the stemmed version of the cleaned data.
# - lemmatized to hold the lemmatized version of the cleaned data.

# %%
# Rename the content columns to original 
news_df.rename(columns = {'content':'original'}, inplace = True)
codeup_df.rename(columns = {'content':'original'}, inplace = True)

# %%
## Starting with the news_df

news_df['clean'] = news_df['original']

#apply the basic_clean, tokenize, and remove_stopwords functions
news_df['clean'] = news_df['clean'].apply(basic_clean).apply(tokenize).apply(remove_stopwords)

#create the stemmed column
news_df['stemmed'] = news_df['clean']

#apply the stem function
news_df['stemmed'] = news_df['stemmed'].apply(stem)

#create the lematize column
news_df['lemmatized'] = news_df['clean']

#apply the lemmatize function
news_df['lemmatized'] = news_df['lemmatized'].apply(lemmatize)

news_df
# Out:
#          category                                              title  \
# 0        business   Rupee hits record low of 79.97 against US dollar
# 1        business  Rupee closes at an all-time low of 79.98 again...
# 2        business  BCCI had ₹40 cr in bank when I joined & ₹47,68...
# 3        business  A fighter to the core: Mahindra praises PV Sin...
# 4        business  It is not a sacrifice at all: Bill Gates on pl...
# ..            ...                                                ...
# 95  entertainment  Excited to announce my next film starring Kart...
# 96  entertainment  8-yr-old Aditya Patil wins Dance Deewane Junio...
# 97  entertainment  Grace & style of Dhanush is something to behol...
# 98  entertainment  Rajesh Khanna was very generous, he bought hou...
# 99  entertainment  Had no money, cried myself to sleep: Monica Ch...
#
#             author       date  \
# 0   Ridham Gambhir 2022-07-18
# 1   Ridham Gambhir 2022-07-18
# 2   Ridham Gambhir 2022-07-17
# 3   Ridham Gambhir 2022-07-17
# 4      Hiral Goyal 2022-07-17
# ..             ...        ...
# 95  Amartya Sharma 2022-07-18
# 96      Udit Gupta 2022-07-18
# 97  Amartya Sharma 2022-07-18
# 98      Udit Gupta 2022-07-18
# 99      Udit Gupta 2022-07-18
#
#                                              original  \
# 0   The rupee hit a record low of 79.97 against th...
# 1   The rupee on Monday hit a fresh record low as ...
# 2   In an Instagram post, Lalit Modi asserted that...
# 3   Businessman Anand Mahindra took to Twitter to ...
# 4   Microsoft Co-founder Bill Gates, who plans to ...
# ..                                                ...
# 95  Filmmaker Kabir Khan took to Instagram to anno...
# 96  Aditya Patil has won the first season of the t...
# 97  Regé-Jean Page, speaking about Dhanush in 'The...
# 98  Veteran actress Sharmila Tagore, who appeared ...
# 99  Actress Monica Chauudhary, known for shows lik...
#
#                                                 clean  \
# 0   rupee hit record low 7997 us dollar monday ope...
# 1   rupee monday hit fresh record low ended closer...
# 2   instagram post lalit modi asserted neither too...
# 3   businessman anand mahindra took twitter praise...
# 4   microsoft cofounder bill gates plans give away...
# ..                                                ...
# 95  filmmaker kabir khan took instagram announce u...
# 96  aditya patil first season talent reality show ...
# 97  regejean page speaking dhanush gray man said g...
# 98  veteran actress sharmila tagore appeared rajes...
# 99  actress monica chauudhary known shows like aph...
#
#                                               stemmed  \
# 0   rupe hit record low 7997 us dollar monday open...
# 1   rupe monday hit fresh record low end closer 80...
# 2   instagram post lalit modi assert neither took ...
# 3   businessman anand mahindra took twitter prais ...
# 4   microsoft cofound bill gate plan give away wea...
# ..                                                ...
# 95  filmmak kabir khan took instagram announc upco...
# 96  aditya patil first season talent realiti show ...
# 97  regejean page speak dhanush gray man said grac...
# 98  veteran actress sharmila tagor appear rajesh k...
# 99  actress monica chauudhari known show like apha...
#
#                                            lemmatized
# 0   rupee hit record low 7997 u dollar monday open...
# 1   rupee monday hit fresh record low ended closer...
# 2   instagram post lalit modi asserted neither too...
# 3   businessman anand mahindra took twitter praise...
# 4   microsoft cofounder bill gate plan give away w...
# ..                                                ...
# 95  filmmaker kabir khan took instagram announce u...
# 96  aditya patil first season talent reality show ...
# 97  regejean page speaking dhanush gray man said g...
# 98  veteran actress sharmila tagore appeared rajes...
# 99  actress monica chauudhary known show like apha...
#
# [100 rows x 8 columns]

# %%
## Now apply the same to the codeup_df

codeup_df['clean'] = codeup_df['original']

#apply the basic_clean, tokenize, and remove_stopwords functions
codeup_df['clean'] = codeup_df['clean'].apply(basic_clean).apply(tokenize).apply(remove_stopwords)

#create the stemmed column
codeup_df['stemmed'] = codeup_df['clean']

#apply the stem function
codeup_df['stemmed'] = codeup_df['stemmed'].apply(stem)

#create the lematize column
codeup_df['lemmatized'] = codeup_df['clean']

#apply the lemmatize function
codeup_df['lemmatized'] = codeup_df['lemmatized'].apply(lemmatize)

codeup_df
# Out:
#                                                 title       date  \
# 0   In-Person Workshop: Learn to Code – Python on ... 2022-06-20
# 1   Free JavaScript Workshop at Codeup Dallas on 6/28 2022-06-19
# 2   Is Our Cloud Administration Program Right for ... 2022-06-08
# 3                                 PRIDE in Tech Panel 2022-06-05
# 4   Inclusion at Codeup During Pride Month (and Al... 2022-06-01
# 5                    Mental Health First Aid Training 2022-05-31
# 6   Codeup Dallas: How to Succeed at a Coding Boot... 2022-05-23
# 7   5 Reasons To Attend Our New Cloud Administrati... 2022-05-17
# 8                       Learn to Code: Python on 5/21 2022-05-16
# 9                      Codeup Dallas Joins Career Day 2022-05-16
# 10  Project Quest Info Session: IT Jumpstart on Ma... 2022-05-11
# 11  From Bootcamp to Bootcamp | A Military Appreci... 2022-04-27
# 12  Our Acquisition of the Rackspace Cloud Academy... 2022-04-14
# 13                  Learn to Code: HTML & CSS on 4/30 2022-04-01
# 14             Learn to Code: Python Workshop on 4/23 2022-03-31
#
#                          category  \
# 0                     San Antonio
# 1                          Dallas
# 2                        Featured
# 3                          Dallas
# 4                     Codeup News
# 5   Tips for Prospective Students
# 6                          Dallas
# 7                     Codeup News
# 8                          Events
# 9                     Codeup News
# 10                    San Antonio
# 11                 Alumni Stories
# 12                    Codeup News
# 13                        Virtual
# 14                         Events
#
#                                              original  \
# 0   According to LinkedIn, the “#1 Most Promising ...
# 1   Event Info:  Location – Codeup Dallas Time – 6...
# 2   Changing careers can be scary. The first thing...
# 3   In celebration of PRIDE month, join our Codeup...
# 4   Happy Pride Month! Pride Month is a dedicated ...
# 5   As a student of Codeup, going through a massiv...
# 6   This event is the perfect opportunity for peop...
# 7   Come Work In The Cloud When your Monday rolls ...
# 8   According to LinkedIn, the “#1 Most Promising ...
# 9   Last week our Codeup Dallas team participated ...
# 10  Join our grant partner Project Quest as they d...
# 11  In honor of Military Appreciation Month, join ...
# 12  Just about a year ago on April 16th, 2021 we a...
# 13  HTML & CSS are the design building blocks of a...
# 14  According to LinkedIn, the “#1 Most Promising ...
#
#                                                 clean  \
# 0   according linkedin 1 promising job data scienc...
# 1   event info location codeup dallas time 6 pm co...
# 2   changing careers scary first thing may asking ...
# 3   celebration pride month join codeup alumni lgb...
# 4   happy pride month pride month dedicated time c...
# 5   student codeup going massive career transition...
# 6   event perfect opportunity people wondering exp...
# 7   come work cloud monday rolls around start get ...
# 8   according linkedin 1 promising job data scienc...
# 9   last week codeup dallas team participated care...
# 10  join grant partner project quest discuss lates...
# 11  honor military appreciation month join us disc...
# 12  year ago april 16th 2021 announced acquisition...
# 13  html css design building blocks websites inter...
# 14  according linkedin 1 promising job data scienc...
#
#                                               stemmed  \
# 0   accord linkedin 1 promis job data scienc one m...
# 1   event info locat codeup dalla time 6 pm come l...
# 2   chang career scari first thing may ask begin l...
# 3   celebr pride month join codeup alumni lgbtqia ...
# 4   happi pride month pride month dedic time celeb...
# 5   student codeup go massiv career transit mental...
# 6   event perfect opportun peopl wonder expect cod...
# 7   come work cloud monday roll around start get s...
# 8   accord linkedin 1 promis job data scienc one m...
# 9   last week codeup dalla team particip career da...
# 10  join grant partner project quest discuss lates...
# 11  honor militari appreci month join us discuss c...
# 12  year ago april 16th 2021 announc acquisit rack...
# 13  html css design build block websit interact da...
# 14  accord linkedin 1 promis job data scienc codeu...
#
#                                            lemmatized
# 0   according linkedin 1 promising job data scienc...
# 1   event info location codeup dallas time 6 pm co...
# 2   changing career scary first thing may asking b...
# 3   celebration pride month join codeup alumnus lg...
# 4   happy pride month pride month dedicated time c...
# 5   student codeup going massive career transition...
# 6   event perfect opportunity people wondering exp...
# 7   come work cloud monday roll around start get s...
# 8   according linkedin 1 promising job data scienc...
# 9   last week codeup dallas team participated care...
# 10  join grant partner project quest discus latest...
# 11  honor military appreciation month join u discu...
# 12  year ago april 16th 2021 announced acquisition...
# 13  html cs design building block website interact...
# 14  according linkedin 1 promising job data scienc...
